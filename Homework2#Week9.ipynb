# %% [markdown]
# ## Get Data with API

# %%
import pandas as pd
import requests

url = 'https://api.covid19api.com/summary'
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
json = r.json()
json
# Out:
# {'Countries': [{'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Date': '2021-07-04T16:35:02.155Z',
#    'ID': 'ad9892e2-29c8-489d-93e6-e4dd9e1522c7',
#    'NewConfirmed': 0,
#    'NewDeaths': 0,
#    'NewRecovered': 0,
#    'Premium': {},
#    'Slug': 'afghanistan',
#    'TotalConfirmed': 120216,
#    'TotalDeaths': 4962,
#    'TotalRecovered': 73635},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Date': '2021-07-04T16:35:02.155Z',
#    'ID': '1658d396-813f-4623-af1d-fc61151bc407',
#    'NewConfirmed': 0,
#    'NewDeaths': 0,
#    'NewRecovered': 0,
#    'Premium': {},
#    'Slug': 'albania',
#    'TotalConfirmed': 132534,
#    'TotalDeaths': 2456,
#    'TotalRecovered': 130023},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Date': '2021-07-04T16:35:02.155Z',
#    'ID': '49b72dd4-4ff1-4515-82c7-864d91c6b49e',
#    'NewConfirmed': 0,
#    'NewDeaths': 0,
#    'NewRecovered': 0,
#    'Premium': {},
#    'Slug': 'algeria',
# ...

# %%
print(json.keys())
df = pd.DataFrame(json['Countries'])
df
# Out:
# dict_keys(['ID', 'Message', 'Global', 'Countries', 'Date'])
#                                        ID  ... Premium
# 0    ad9892e2-29c8-489d-93e6-e4dd9e1522c7  ...      {}
# 1    1658d396-813f-4623-af1d-fc61151bc407  ...      {}
# 2    49b72dd4-4ff1-4515-82c7-864d91c6b49e  ...      {}
# 3    48dfdd55-d22c-4190-854a-6f95889e093b  ...      {}
# 4    713786d2-24a2-4f7b-96de-c80e489896ab  ...      {}
# ..                                    ...  ...     ...
# 187  1322476e-e5ff-4b9f-b117-f247c22c2f94  ...      {}
# 188  99b82230-dc31-4f7a-abec-641697a8c5d8  ...      {}
# 189  b27fdfd0-c8b4-4afb-b757-88ca896e64b2  ...      {}
# 190  997a8fc6-000a-494c-9863-350101595567  ...      {}
# 191  96fd3bf2-2f3c-46c6-bcaa-ee785d0086d4  ...      {}
#
# [192 rows x 12 columns]
